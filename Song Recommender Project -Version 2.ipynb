# %% [markdown]
# # Song Recommender Project

# %% [markdown]
# The goal of this notebook is to develop a new Song Recommender product based on Billboard - The Hot 100 list: (https://www.billboard.com/charts/hot-100/).
#
# When the user enters the name of a song included in the hot list, the Song Recommender will suggest another song from the hot list.
#
# In case the song entered by the user is not included in the Billboard list anymore, the Song Recommender will conect with Spotify in order to find another song with the same features of the one entered by the user, and recommend it.
#
# Song Recommender will base its recommendations on the following features:
#
# * **Danceability**: Danceability describes how suitable for dancing a track is, based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# * **Acousticness**: A measure from 0.0 to 1.0 of whether the track is acoustic.
#
# * **Energy**: Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy.
#
# * **Instrumentalness**: Predicts whether a track contains no vocals. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content.
#
# * **Liveness**: Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live.
#
# * **Loudness**: The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track. Values typical range between -60 and 0 db.
#
# * **Speechiness**: Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value.
#
# * **Tempo**: The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# * **Valence**: A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).

# %%
# Import all necessary libraries:

import numpy as np
import pandas as pd
import spotipy as sp
import config
from time import sleep
from random import randint
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import random 
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score
from IPython.display import Image
from IPython.display import display
from IPython.display import IFrame
from sklearn.metrics import pairwise_distances_argmin_min

# %%
#import files form "Spotify Clustering" Notebook (Notebook available in the repository)

def load(filename = "filename.pickle"): 
    try: 
        with open(filename, "rb") as f: 
            return pickle.load(f) 
    except FileNotFoundError: 
        print("File not found!")

# %%
# #import files form "Spotify Clustering" Notebook (Notebook available in the repository)
scaler2 = load("Model/scaler.pickle")
scaler2
# Out:
# StandardScaler()

# %%
#import files form "Spotify Clustering" Notebook (Notebook available in the repository)
kmeans2 = load("Model/kmeans_4.pickle")
kmeans2
# Out:
# KMeans(n_clusters=6, random_state=1234)

# %% [markdown]
# # Loading data

# %%
billboard_df=pd.read_csv("Data/hot100.csv") #import files form "Bilboard-The hot 100" Notebook (Notebook available in the repository)

clus_df=pd.read_csv("Data/clustered_df_v2.csv")#import files form "Spotify Clustering" Notebook (Notebook available in the repository)

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=config.client_id,
                                                           client_secret=config.client_secret)) # Credentials to connect to Spotify

# %%
#Let's check our DataFrame
billboard_df
# Out:
#                                               artists  \
# 0                                       glass animals
# 1   carolina gaitan, mauro castillo, adassa, rhenz...
# 2                                               gayle
# 3                                         kodak black
# 4                       the kid laroi & justin bieber
# ..                                                ...
# 95                                      mary j. blige
# 96                               king von & 21 savage
# 97                          saweetie featuring h.e.r.
# 98                                      blake shelton
# 99                                  lil shordie scott
#
#                            titles
# 0                      heat waves
# 1       we don't talk about bruno
# 2                         abcdefu
# 3                   super gremlin
# 4                            stay
# ..                            ...
# 95          good morning gorgeous
# 96                don't play that
# 97                         closer
# 98     come back as a country boy
# 99  rocking a cardigan in atlanta
#
# [100 rows x 2 columns]

# %%
billboard_df.rename(columns = {'artists' : 'artist', 'titles' : 'song_name'}, inplace = True)
billboard_df
# Out:
#                                                artist  \
# 0                                       glass animals
# 1   carolina gaitan, mauro castillo, adassa, rhenz...
# 2                                               gayle
# 3                                         kodak black
# 4                       the kid laroi & justin bieber
# ..                                                ...
# 95                                      mary j. blige
# 96                               king von & 21 savage
# 97                          saweetie featuring h.e.r.
# 98                                      blake shelton
# 99                                  lil shordie scott
#
#                         song_name
# 0                      heat waves
# 1       we don't talk about bruno
# 2                         abcdefu
# 3                   super gremlin
# 4                            stay
# ..                            ...
# 95          good morning gorgeous
# 96                don't play that
# 97                         closer
# 98     come back as a country boy
# 99  rocking a cardigan in atlanta
#
# [100 rows x 2 columns]

# %%
clus_df
# Out:
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.776   0.378    0    -8.035     1       0.0322        0.4350
# 1              0.663   0.697    0    -5.503     1       0.0508        0.2720
# 2              0.596   0.675    9    -7.790     1       0.0517        0.1880
# 3              0.593   0.274    2   -15.402     1       0.2780        0.9340
# 4              0.871   0.281    9   -10.650     0       0.0466        0.7670
# ...              ...     ...  ...       ...   ...          ...           ...
# 222308         0.906   0.724    6    -4.109     0       0.0931        0.4460
# 222309         0.934   0.443    1    -7.541     1       0.4100        0.0272
# 222310         0.903   0.447    6   -11.554     1       0.1160        0.0873
# 222311         0.805   0.835    0    -4.603     1       0.0896        0.1300
# 222312         0.789   0.858    5    -4.388     1       0.0404        0.2200
#
#         instrumentalness  liveness  valence  ...  time_signature  cluster  \
# 0               0.001870    0.1100    0.453  ...               4        1
# 1               0.008860    0.1530    0.873  ...               4        1
# 2               0.739000    0.1020    0.155  ...               4        4
# 3               0.000569    0.0758    0.346  ...               4        0
# 4               0.000180    0.1470    0.541  ...               4        3
# ...                  ...       ...      ...  ...             ...      ...
# 222308          0.000000    0.0848    0.744  ...               4        3
# 222309          0.000000    0.0889    0.359  ...               4        5
# 222310          0.000000    0.1360    0.239  ...               4        1
# 222311          0.000005    0.3650    0.722  ...               4        1
# 222312          0.000046    0.3350    0.491  ...               4        1
#
#                   type                      id  \
# 0       audio_features  2EgfLUS0jNiujIWc3ZLEtn
# 1       audio_features  2ngRZDAluwYoJeuqEA4dhK
# 2       audio_features  3tcJ3yUXKtJpsgpAyVzP7R
# 3       audio_features  6W4osAjSVCvUwOlVFBP76n
# 4       audio_features  1vdpFZ4rsQevl8WC6m3m9y
# ...                ...                     ...
# 222308  audio_features  4dUlJyHgdz6IeCJIYMHHDm
# 222309  audio_features  051wt8AyLFgYnVuberd3vO
# 222310  audio_features  3DyiAk1BzIF8rq9rimypG4
# 222311  audio_features  1EJgymgJHcjSOGSHcYaxvW
# 222312  audio_features  3vQhEd4lOg4mAV6CHCgoHW
#
#                                          uri  \
# 0       spotify:track:2EgfLUS0jNiujIWc3ZLEtn
# 1       spotify:track:2ngRZDAluwYoJeuqEA4dhK
# 2       spotify:track:3tcJ3yUXKtJpsgpAyVzP7R
# 3       spotify:track:6W4osAjSVCvUwOlVFBP76n
# 4       spotify:track:1vdpFZ4rsQevl8WC6m3m9y
# ...                                      ...
# 222308  spotify:track:4dUlJyHgdz6IeCJIYMHHDm
# 222309  spotify:track:051wt8AyLFgYnVuberd3vO
# 222310  spotify:track:3DyiAk1BzIF8rq9rimypG4
# 222311  spotify:track:1EJgymgJHcjSOGSHcYaxvW
# 222312  spotify:track:3vQhEd4lOg4mAV6CHCgoHW
#
#                                                track_href  \
# 0       https://api.spotify.com/v1/tracks/2EgfLUS0jNiu...
# 1       https://api.spotify.com/v1/tracks/2ngRZDAluwYo...
# 2       https://api.spotify.com/v1/tracks/3tcJ3yUXKtJp...
# 3       https://api.spotify.com/v1/tracks/6W4osAjSVCvU...
# 4       https://api.spotify.com/v1/tracks/1vdpFZ4rsQev...
# ...                                                   ...
# 222308  https://api.spotify.com/v1/tracks/4dUlJyHgdz6I...
# 222309  https://api.spotify.com/v1/tracks/051wt8AyLFgY...
# 222310  https://api.spotify.com/v1/tracks/3DyiAk1BzIF8...
# 222311  https://api.spotify.com/v1/tracks/1EJgymgJHcjS...
# 222312  https://api.spotify.com/v1/tracks/3vQhEd4lOg4m...
#
#                                              analysis_url  \
# 0       https://api.spotify.com/v1/audio-analysis/2Egf...
# 1       https://api.spotify.com/v1/audio-analysis/2ngR...
# 2       https://api.spotify.com/v1/audio-analysis/3tcJ...
# 3       https://api.spotify.com/v1/audio-analysis/6W4o...
# 4       https://api.spotify.com/v1/audio-analysis/1vdp...
# ...                                                   ...
# 222308  https://api.spotify.com/v1/audio-analysis/4dUl...
# 222309  https://api.spotify.com/v1/audio-analysis/051w...
# 222310  https://api.spotify.com/v1/audio-analysis/3Dyi...
# 222311  https://api.spotify.com/v1/audio-analysis/1EJg...
# 222312  https://api.spotify.com/v1/audio-analysis/3vQh...
#
#                                                track_name artist_name  \
# 0                                               Tangerine   Tim Atlas
# 1                                                Sidestep   Tim Atlas
# 2                                        Crime of Passion   Tim Atlas
# 3                                         Together Lonely   Tim Atlas
# 4                                              Small Talk   Tim Atlas
# ...                                                   ...         ...
# 222308        Me Gusta - Remix (feat. Cardi B & 24kGoldn)     Cardi B
# 222309                    WAP (feat. Megan Thee Stallion)     Cardi B
# 222310                                    La Bebe - Remix     Cardi B
# 222311  South of the Border (feat. Camila Cabello & Ca...     Cardi B
# 222312  South of the Border (feat. Camila Cabello & Ca...     Cardi B
#
#                      artist_id
# 0       3CiuXDKttPUT0tWGHicFUH
# 1       3CiuXDKttPUT0tWGHicFUH
# 2       3CiuXDKttPUT0tWGHicFUH
# 3       3CiuXDKttPUT0tWGHicFUH
# 4       3CiuXDKttPUT0tWGHicFUH
# ...                        ...
# 222308  4kYSro6naA4h99UJvo89HB
# 222309  4kYSro6naA4h99UJvo89HB
# 222310  4kYSro6naA4h99UJvo89HB
# 222311  4kYSro6naA4h99UJvo89HB
# 222312  4kYSro6naA4h99UJvo89HB
#
# [222313 rows x 22 columns]

# %%
clus_df.rename(columns = {'artist_name' : 'artist', 'track_name' : 'song_name'}, inplace = True)
clus_df
# Out:
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.776   0.378    0    -8.035     1       0.0322        0.4350
# 1              0.663   0.697    0    -5.503     1       0.0508        0.2720
# 2              0.596   0.675    9    -7.790     1       0.0517        0.1880
# 3              0.593   0.274    2   -15.402     1       0.2780        0.9340
# 4              0.871   0.281    9   -10.650     0       0.0466        0.7670
# ...              ...     ...  ...       ...   ...          ...           ...
# 222308         0.906   0.724    6    -4.109     0       0.0931        0.4460
# 222309         0.934   0.443    1    -7.541     1       0.4100        0.0272
# 222310         0.903   0.447    6   -11.554     1       0.1160        0.0873
# 222311         0.805   0.835    0    -4.603     1       0.0896        0.1300
# 222312         0.789   0.858    5    -4.388     1       0.0404        0.2200
#
#         instrumentalness  liveness  valence  ...  time_signature  cluster  \
# 0               0.001870    0.1100    0.453  ...               4        1
# 1               0.008860    0.1530    0.873  ...               4        1
# 2               0.739000    0.1020    0.155  ...               4        4
# 3               0.000569    0.0758    0.346  ...               4        0
# 4               0.000180    0.1470    0.541  ...               4        3
# ...                  ...       ...      ...  ...             ...      ...
# 222308          0.000000    0.0848    0.744  ...               4        3
# 222309          0.000000    0.0889    0.359  ...               4        5
# 222310          0.000000    0.1360    0.239  ...               4        1
# 222311          0.000005    0.3650    0.722  ...               4        1
# 222312          0.000046    0.3350    0.491  ...               4        1
#
#                   type                      id  \
# 0       audio_features  2EgfLUS0jNiujIWc3ZLEtn
# 1       audio_features  2ngRZDAluwYoJeuqEA4dhK
# 2       audio_features  3tcJ3yUXKtJpsgpAyVzP7R
# 3       audio_features  6W4osAjSVCvUwOlVFBP76n
# 4       audio_features  1vdpFZ4rsQevl8WC6m3m9y
# ...                ...                     ...
# 222308  audio_features  4dUlJyHgdz6IeCJIYMHHDm
# 222309  audio_features  051wt8AyLFgYnVuberd3vO
# 222310  audio_features  3DyiAk1BzIF8rq9rimypG4
# 222311  audio_features  1EJgymgJHcjSOGSHcYaxvW
# 222312  audio_features  3vQhEd4lOg4mAV6CHCgoHW
#
#                                          uri  \
# 0       spotify:track:2EgfLUS0jNiujIWc3ZLEtn
# 1       spotify:track:2ngRZDAluwYoJeuqEA4dhK
# 2       spotify:track:3tcJ3yUXKtJpsgpAyVzP7R
# 3       spotify:track:6W4osAjSVCvUwOlVFBP76n
# 4       spotify:track:1vdpFZ4rsQevl8WC6m3m9y
# ...                                      ...
# 222308  spotify:track:4dUlJyHgdz6IeCJIYMHHDm
# 222309  spotify:track:051wt8AyLFgYnVuberd3vO
# 222310  spotify:track:3DyiAk1BzIF8rq9rimypG4
# 222311  spotify:track:1EJgymgJHcjSOGSHcYaxvW
# 222312  spotify:track:3vQhEd4lOg4mAV6CHCgoHW
#
#                                                track_href  \
# 0       https://api.spotify.com/v1/tracks/2EgfLUS0jNiu...
# 1       https://api.spotify.com/v1/tracks/2ngRZDAluwYo...
# 2       https://api.spotify.com/v1/tracks/3tcJ3yUXKtJp...
# 3       https://api.spotify.com/v1/tracks/6W4osAjSVCvU...
# 4       https://api.spotify.com/v1/tracks/1vdpFZ4rsQev...
# ...                                                   ...
# 222308  https://api.spotify.com/v1/tracks/4dUlJyHgdz6I...
# 222309  https://api.spotify.com/v1/tracks/051wt8AyLFgY...
# 222310  https://api.spotify.com/v1/tracks/3DyiAk1BzIF8...
# 222311  https://api.spotify.com/v1/tracks/1EJgymgJHcjS...
# 222312  https://api.spotify.com/v1/tracks/3vQhEd4lOg4m...
#
#                                              analysis_url  \
# 0       https://api.spotify.com/v1/audio-analysis/2Egf...
# 1       https://api.spotify.com/v1/audio-analysis/2ngR...
# 2       https://api.spotify.com/v1/audio-analysis/3tcJ...
# 3       https://api.spotify.com/v1/audio-analysis/6W4o...
# 4       https://api.spotify.com/v1/audio-analysis/1vdp...
# ...                                                   ...
# 222308  https://api.spotify.com/v1/audio-analysis/4dUl...
# 222309  https://api.spotify.com/v1/audio-analysis/051w...
# 222310  https://api.spotify.com/v1/audio-analysis/3Dyi...
# 222311  https://api.spotify.com/v1/audio-analysis/1EJg...
# 222312  https://api.spotify.com/v1/audio-analysis/3vQh...
#
#                                                 song_name     artist  \
# 0                                               Tangerine  Tim Atlas
# 1                                                Sidestep  Tim Atlas
# 2                                        Crime of Passion  Tim Atlas
# 3                                         Together Lonely  Tim Atlas
# 4                                              Small Talk  Tim Atlas
# ...                                                   ...        ...
# 222308        Me Gusta - Remix (feat. Cardi B & 24kGoldn)    Cardi B
# 222309                    WAP (feat. Megan Thee Stallion)    Cardi B
# 222310                                    La Bebe - Remix    Cardi B
# 222311  South of the Border (feat. Camila Cabello & Ca...    Cardi B
# 222312  South of the Border (feat. Camila Cabello & Ca...    Cardi B
#
#                      artist_id
# 0       3CiuXDKttPUT0tWGHicFUH
# 1       3CiuXDKttPUT0tWGHicFUH
# 2       3CiuXDKttPUT0tWGHicFUH
# 3       3CiuXDKttPUT0tWGHicFUH
# 4       3CiuXDKttPUT0tWGHicFUH
# ...                        ...
# 222308  4kYSro6naA4h99UJvo89HB
# 222309  4kYSro6naA4h99UJvo89HB
# 222310  4kYSro6naA4h99UJvo89HB
# 222311  4kYSro6naA4h99UJvo89HB
# 222312  4kYSro6naA4h99UJvo89HB
#
# [222313 rows x 22 columns]

# %% [markdown]
# # Connect with Spotify

# %%
# Conect with Spotify in order to get the most important features of a song: 

#def spotify_search():


results = sp.search(q='lose yourself', limit=1)

# %%
#Extract the track id
track_ids = [track['id'] for track in results['tracks']['items']]

# extract the audio features
audio_features = sp.audio_features(track_ids)

# store audio features in a dataframe
audio_df = pd.DataFrame(audio_features)
audio_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.689   0.735    2    -4.545     1        0.267       0.00922
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0           0.00072     0.365    0.059  171.403  audio_features
#
#                        id                                   uri  \
# 0  77Ft1RJngppZlq59B6uP0z  spotify:track:77Ft1RJngppZlq59B6uP0z
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/77Ft1RJngppZ...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/77Ft...       320627
#
#    time_signature
# 0               4

# %%
# create a function to automate work
def get_audio_features():
    # get tracks from artist
    results = sp.search(q=f'track:{song_name}', limit=1)
    # extract the track ids
    track_ids = [track['id'] for track in results['tracks']['items']]
    song_names = [track['name'] for track in results['tracks']['items']]
    # extract the audio features
    audio_features = sp.audio_features(track_ids)
    # store audio features in a dataframe
    audio_df = pd.DataFrame(audio_features)
    audio_df['artist'] = artist
    audio_df['song name'] = song_names
    return audio_df

# %%
# We get numerical columns:
X=audio_df._get_numeric_data()

# %%
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns)
display(X.head())
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.689   0.735    2    -4.545     1        0.267       0.00922
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0           0.00072     0.365    0.059  171.403       320627               4

# %%
clusters = kmeans2.predict(X_scaled_df)

# %%
clusters
# Out:
# array([1])

# %% [markdown]
# # Create the recommender function

# %%
choice=["is a great choice!"," is amazing!","is cool!"]
hot_song=""

def recommended_song():
    hot_song,hot_artist =input("Please enter a song name and the artist name: ").split(",")
    print("hot song is:",hot_song)
    print("hot artist is:",hot_artist)
    
    song_name=hot_song.lower()
    artist_name=hot_artist.lower()

    if song_name in billboard_df["song_name"].values:
        print(song_name,random.choice(choice),"You might like this one from the hot list too:",random.choice(billboard_df["song_name"]))                                                                             
    elif artist_name in billboard_df["artist"].values:
        print(song_name,random.choice(choice),"You might like this one from the hot list too:",random.choice(billboard_df["song_name"]))
        
  
    else:
        results = sp.search(q=f'track:{song_name}', limit=1)
        track_id = results['tracks']['items'][0]['id']
        audio_features = sp.audio_features(track_id)
        df_ = pd.DataFrame(audio_features)
        x = df_[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
        closest, _ = pairwise_distances_argmin_min(x, clus_df[x.columns])
        return ' - '.join([clus_df.loc[closest]['song_name'].values[0], clus_df.loc[closest]['artist'].values[0]])

# %%
recommended_song()
# Out:
# Please enter a song name and the artist name: let her go, passengers
# hot song is: let her go
# hot artist is:  passengers
# 'Let Her Go - Harry Styles'

# %%
billboard_df["artist"].value_counts()
# Out:
# kodak black                                3
# nicki minaj x lil baby                     2
# adele                                      2
# doja cat                                   2
# ed sheeran                                 2
#                                           ..
# drake featuring 21 savage & project pat    1
# ckay                                       1
# morgan wallen                              1
# doja cat & the weeknd                      1
# lil shordie scott                          1
# Name: artist, Length: 93, dtype: int64

# %%
clus_df.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'time_signature', 'cluster', 'type', 'id', 'uri',
#        'track_href', 'analysis_url', 'song_name', 'artist', 'artist_id'],
#       dtype='object')
